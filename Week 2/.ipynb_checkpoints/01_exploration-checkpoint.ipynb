# %%
import pandas as pd

# %%
main_df = pd.DataFrame()
for i in range(1,13):
    if i < 10:
        month = "0"+str(i)
    else:
        month = str(i)
    try:
        df = pd.read_csv("CRMLSSold2025"+month)
        pd.concat()
    except:
        df = pd.read_csv("CRMLSSold2025"+month+"_filled")
